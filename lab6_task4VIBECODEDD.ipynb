# %%
# Sample csv file with well's name and API#:

# well 1:
# Name: Carson SWD 5301 12-24
# API#: 33-053-90329

# well 2:
# Name: Atlanta #1 SWD
# API#: 33-105-90258

# well 3:
# Name: Chalmers Wade Federal 5301 44-24 12TXR
# API#: 33-053-06012

# %%
################################################
# STEP 1
################################################
import re
import csv
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

BASE = "https://www.drillingedge.com"
HEADERS = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"}

# Single session so cookies persist across requests
session = requests.Session()
session.headers.update(HEADERS)
session.get(BASE)  # establish session cookie

def search_well_url(well_name: str, api: str) -> str | None:
    # Normalize API: strip trailing completion code like -00 so it matches drillingedge URLs
    # e.g. "33-053-05906-00" -> "33-053-05906"
    
    
    if api:
        api=api.strip()
        params = {"type": "wells", "operator_name":"", "well_name":"", "api_no": api}
    elif well_name is not None:
        well_name=well_name.lower().strip().replace(" ", "-").replace("&", "and")
        short_name = " ".join(well_name.split()[:3])
        params = {"type": "wells", "operator_name":"","well_name": well_name}

    r = session.get(f"{BASE}/search", params=params)
    soup = BeautifulSoup(r.text, "html.parser")
    
    for a in soup.select('a[href*="/wells/"]'):
        href = a.get("href", "")
        full = urljoin(BASE, href)

        if api:
            if api in full:
                return full
            else:
                print("api not matching:",api)
        else:
            if well_name in full:
                return full
            else:
                print("well name not matching:",well_name)
                return full

    return None

# %%
# Read wells_data2.csv (use Python engine + skip bad lines: some rows have unquoted commas or bad quotes in fields)
wells = []
with open("wells_data2.csv", newline='', encoding="utf-8") as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        api = row.get("api_number")
        api = None if api is None or api == "" or api.upper() == "NULL" else api.strip('-00')
        well_dict = {
            "name":   row.get("well_name", None),
            "api":    api
        }
        
        if well_dict["api"] is not None or well_dict["name"] is not None:
            wells.append(well_dict)

# %%
df = pd.DataFrame(wells)
df.loc[df["api"] != "NULL"]
# Out:
#                                                  name           api
# 0                              Basic Game & Fish 34-3           NaN
# 1                            Corps of En ineers 31-10           NaN
# 2                                  Lewis & Clark 2-4H           NaN
# 3   Field/ Prospect: McKenziel County, NDHarper Oi...           NaN
# 4   (see details Footages F L Field Name of Contra...           NaN
# ..                                                ...           ...
# 66                       KLINE FEDERAL 5300 31-18 15T  33-053-06755
# 67  & No. API # County & State SDI Job # Rig Surve...  33-053-08946
# 68                           BUCK SHOT SWD 5300 31-31  33-053-90244
# 69  Atlanta #1 SWD Footages IQtr-Qtr I Section !To...           NaN
# 70                              Carson SWD 5301 12-24           NaN
#
# [71 rows x 2 columns]

# %%
# Search URLs
for well in wells:
#well=wells[2]
    url = search_well_url(well["name"], well["api"])
    well["url"] = url
    print(f"{well['name'][:40]:<40} -> {url or 'NOT FOUND'}")
# Out:
# Basic Game & Fish 34-3                   -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/basic-game-and-fish-34-3/33-053-02102
# well name not matching: corps-of-en-ineers-31-10
# Corps of En ineers 31-10                 -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/corps-of-engineers-31-10/33-053-02148
# Lewis & Clark 2-4H                       -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/lewis-and-clark-2-4h/33-053-02556
# Field/ Prospect: McKenziel County, NDHar -> NOT FOUND
# (see details Footages F L Field Name of  -> NOT FOUND
# Foley Federal 5301 43-12H Original Hole  -> NOT FOUND
# and Numbe r 24-HOUR PRODUCTION RA TE (se -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/yukon-5301-41-12t/33-053-03911
# well name not matching: dahl-15-11h
# DAHL 15-11H                              -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/dahl-federal-15-11h/33-053-03703
# DAHL FEDERAL 2-15H                       -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/dahl-federal-2-15h/33-053-03846
# Magnum 1-36-25H Footages I Qtr-Qtr I Sec -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/magnum-1-36-25h/33-053-03943
# MAGNUM 2-36-25H Oper< tor Telephone Numb -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/magnum-2-36-25h/33-053-03944
# McKenzie County, ND County/State W 103 3 -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/magnum-3-36-25h/33-053-04069
# Ash Federal 5300 11-18T Footages 800 F N -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/ash-federal-5300-11-18t/33-053-04211
# 24-HOUR PRODUCTION RATE Atlanta 14-6H Be -> https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-14-6h/33-105-02719
# Atlanta 13-6H Footages IQtr-Qtr I Sectio -> NOT FOUND
# Atlanta 12-6H Footages I Qtr-Qtr I Secti -> https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-12-6h/33-105-02721
# Atlanta 11-6H Footages IQtr-Qtr I Sectio -> https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-11-6h/33-105-02722
# Atlanta Federal 10-6H Footages IQtr-Qtr  -> https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-federal-10-6h/33-105-02723
# 24-HOUR PRODUCTION RATE Atlanta Federal  -> https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-federal-9-6h/33-105-02724
# Atlanta Federal 8-6H Footages IQtr-Qtr I -> https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-federal-8-6h/33-105-02725
# Atlanta Federal 7-6H Footages IQtr-Qtr I -> https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-federal-7-6h/33-105-02726
# Atlanta Federal 6-6H Atlanta 14 Well Eco -> https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-federal-6-6h/33-105-02727
# Atlanta Federal 6-6H Footages IQtr-Qtr ' -> https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-federal-5-6h/33-105-02728
# Atlanta 4-6H Footages IQtr-Qtr I Section -> https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-4-6h/33-105-02729
# Atlanta 3-6H Footages IQtr-Qtr I Section -> NOT FOUND
# Atlanta 2-6H Footages IQtr-Qtr I Section -> https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-2-6h/33-105-02731
# Atlanta 1-6H Footages lQtr-Qtr 'Section  -> https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-1-6h/33-105-02732
# Cc lumbus Federal 1-16H Op1irator Cc nti -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/columbus-federal-1-16h/33-053-04852
# Tallahassee 3-16H                        -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/tallahassee-3-16h/33-053-04853
# Tallahassee 2-16H                        -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/tallahassee-2-16h/33-053-04854
# Cc1lumbus Federal 2-16H Op1irator Ccinti -> NOT FOUND
# Columbus Federal 3-16H                   -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/columbus-federal-3-16h/33-053-04856
# 24-HOUR PRODUCTION RATE Colville 5301 44 -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/colville-5301-44-12t/33-053-04981
# AP I#: Latitude: Longitude: Datum: Field -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/lewis-federal-5300-21-31-6b/33-053-05845
# Lewis Federal 5300 21-31 5B API #: 33-05 -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/lewis-federal-5300-21-31-5b/33-053-05849
# Wade Federal 5300 31-30 11T Footages . · -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/wade-federal-5300-31-30-11t/33-053-05906
# Chalmers 5301 44-24 2TR Footages IQtr-Qt -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-5301-44-24-2tr/33-053-05924
# Wade Federal 5300 41-30 4T               -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/wade-federal-5300-41-30-4t/33-053-05943
# Wade Federal 5300 41-30 6B               -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/wade-federal-5300-31-30-2b/33-053-05995
# 24-HOUR PRODUCTION RATE Chalmers 5301 44 -> NOT FOUND
# 24-HOUR PRODUCTION RA TE Chalmers 5301 4 -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-5301-44-24-4t2r/33-053-06011
# 0 Deepened Well D Other: N Rf:.<.;,EIVEO -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-wade-federal-5301-44-24-12txr/33-053-06012
# 24-HOUR PRODUCTION RATE Chalmers 5300 21 -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-5300-21-19-5t/33-053-06018
# Chalmers 5300 21-19 6B D Recompletion D  -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-5300-21-19-6b/33-053-06019
# Chalmers 5300 21-19 ST                   -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-5300-21-19-8t/33-053-06021
# Chalmers 5300 21-19 10T Footages IQtr-Qt -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-5300-21-19-10t/33-053-06022
# CHALMERS 5300 21-19 98                   -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-5300-21-19-9b/33-053-06023
# Chalmers 5300 21-19 11 B Received FEB 1  -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-5300-21-19-11b/33-053-06024
# KLINE FEDERAL 5300 41-18 9T              -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/kline-federal-5300-41-18-9t/33-053-06025
# Location: E levation: KB: 2,082' Formati -> NOT FOUND
# 24-HOUR PRODUCTION RATE Kline Federal 53 -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/kline-federal-5300-41-18-13t2x/33-053-06028
# 24-HOUR PRODUCTION RATE Kline Federal 53 -> NOT FOUND
# Kline Federal 5300 41-18 12TX Footages · -> NOT FOUND
# D Deepened Well D Other: Spacing Unit De -> NOT FOUND
# Kline Federal 5300 31-18 8B              -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/wrrmu-4-28/33-053-00605
# KLINE FEDERAL 5300 31-18 7T              -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/kline-federal-5300-31-18-7t/33-053-06056
# Kline Federal 5300 31-18 6B D D D D D D  -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/kline-federal-5300-31-18-6b/33-053-06057
# Wade Federal 5300 21-30 12T D D D D D D  -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/wade-federal-5300-21-30-12t/33-053-06129
# WADE FEDERAL 5300 21-30 13B              -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/wade-federal-5300-21-30-13b/33-053-06131
# Kline Federal 5300 11-18 5B              -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/kline-federal-5300-11-18-5b/33-053-06223
# Kline Federal 5300 11-18 3T              -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/kline-federal-5300-11-18-3t/33-053-06225
# Gramma Federal 5300 41-3112B Footages 64 -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/gramma-federal-5300-41-31-12b/33-053-06231
# Qtr-Qtr Section Township Range County ~G -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/gramma-federal-5300-41-31-13t/33-053-06232
# Kline Federal 5300 11-18 2B Footages IQt -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/kline-federal-5300-11-18-2b/33-053-06243
# & No. API # County & State SDI Job # Rig -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/lewis-federal-5300-11-31-3b/33-053-06548
# & No. API # County & State SDI Job # Rig -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/lewis-federal-5300-11-31-2b/33-053-06549
# KLINE FEDERAL 5300 31-18 15T             -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/kline-federal-5300-31-18-15t/33-053-06755
# & No. API # County & State SDI Job # Rig -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/lewis-federal-5300-11-31-4br/33-053-08946
# BUCK SHOT SWD 5300 31-31                 -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/buck-shot-swd-5300-31-31/33-053-90244
# Atlanta #1 SWD Footages IQtr-Qtr I Secti -> NOT FOUND
# Carson SWD 5301 12-24                    -> https://www.drillingedge.com/north-dakota/mckenzie-county/wells/carson-swd-5301-12-24/33-053-90329

# %%
wells
# Out:
# [{'name': 'Basic Game & Fish 34-3', 'api': None},
#  {'name': 'Corps of En ineers 31-10', 'api': None},
#  {'name': 'Lewis & Clark 2-4H', 'api': None},
#  {'name': 'Field/ Prospect: McKenziel County, NDHarper Oil Company Well Information 8 3/4 to 11',
#   'api': None},
#  {'name': '(see details Footages F L Field Name of Contractor(s)',
#   'api': None},
#  {'name': 'Foley Federal 5301 43-12H Original Hole NDIC File No. 20863 Location: Section 12-T153N-R101W County/State: McKenzie County, ND Surveyed From a Depth of: 2,186’ MD to 12,283’ MD Type of Survey: Magnetic MWD Name(s) of MWD Supervisor(s): John Capra / Brandon Ramirez The data and calculations for this survey have been checked by me and conform to the standards and procedures set forth by Professional Directional Ltd. This report represents a true and correct Directional Survey of this well based on the original data obtained at the well site. The survey was calculated using the minimum curvature method. Robert D. Hays / Well Planner',
#   'api': None},
#  {'name': 'and Numbe r 24-HOUR PRODUCTION RA TE (see details) Before After Footages L IQtr-Qtr I Section I Township I Range F L F 12 153 N 101 w Oil Bbls Oil Water Bbls Water Field I Pool I County Baker Bakken McKenzie Gas MCF Gas Name of Contractor(s)',
#   'api': '33-053-03911'},
#  {'name': 'DAHL 15-11H', 'api': None},
#  {'name': 'DAHL FEDERAL 2-15H', 'api': None},
#  {'name': "Magnum 1-36-25H Footages I Qtr-Qtr I Section 250 FS L 815 F WL SWSW 38 Field l~ken Baker D Drilling Prognosis IZI Redrilling or Repair D casing or Liner D PlugWell 0 Supplemental Hlllllory D Temporarily Abandon D Other !Township I Range 153 N 101 w I County McKenzie 'City DETAILS OF WORK D D D D D D !Well Fie No. 22247 SpRI Report Shooting Acidlzlng Fracture Treatment Change Production Method Reclamation zu.IOUR PRODUCTION RATE Before After Oil Bbfs Oil Water Bbls Water Gas MCF Gas 'State 'Zip Code Bbls Bbls MCF Slawson Exploration Company, Inc. (SECI) will perform remedial work on the Magnum 1-36-25H well. Attached with this fonn Is the procedure of work to be completed and the well bore diagram for your review. Company Slawson Exploration Company, Inc.",
#   'api': '33-053-03943'},
#  {'name': 'MAGNUM 2-36-25H Oper< tor Telephone Number 720-457 -9820 All of Sect 36 & 25 T153N R101W Field Slawson Exploration Com an , Inc. BAKER Pool Suite 1600 Bakken City State Zip Code Permit Type Denver CO 80202 D Wildcat 0 Development D Extension ~-----------_._ ___ _._ ________ _._-=~...;,_;;..;...;. ___ _=:_...;,_....:....._;_...;,_ _ ___. __ __;,.;_;,...;,_ __ ~ LOCATION OF WELL -At Su1face Otr-Qtr I Section !Township I Range County 205 F s L 240 F E L SESE 36 153 N 101 w McKenzie -Spud Date I Date TD Reached Drilling Contractor and Rig Number I KB Elevation (Ft) Graded Elevation (Ft) 3/1812012 4/27/2012 Nabors #419 2177 2156 -Type of Electric and Other Logs Run (See Instructions) Tripl 1e Combo - OIL, CNL, COL with GR to surface CBL/GR/CCL CASING & TUBULARS RECORD (Report all strin! s set in well) w Surfac Vertie Latera ~II Bore ;e Hole 11 Hole 11 Type Surface Intermediate Liner String Size (Inch) 9 5/8 7 4 1/2 Top Set Depth Set (MD Ft) (MD Ft) 0 2168 0 11104 9082 20705 Hole Size Weight Anchor Set Packer Set Sacks Top of (Inch) (Lbs/Ft) (MD Ft) (MD Ft) Cement Cement 13 1/2 36 835 8 3/4 29 & 32 1025 2200 6 11.6 9082 PERFORATION & OPEN HOLE INTERVALS - Well Bore TD Open Hole/Perforated Kick-off Top of Weill Bore Drillers Depth Completion Interval (MD.Ft) Point Casing Type Window (MD Ft) Top Bottom (MD Ft) (MD Ft) -Latera !1 20728 Other 11104 20705 10282 11104 -- ~ ------ PRODUCTION Curren Producing Open Hole or Perforated lnterval(s )',
#   'api': '33-053-03944'},
#  {'name': 'McKenzie County, ND County/State W 103 36\' 16.88040 Surface Longitude Nabors 419 Rig Contractor/ Name 0 to 9319 ft Measurements While Drilling (MWD) ft Jeromy Haggerty Slawson Company ND-SLW-0038 Job Number N 48 1\' 29.71560" Surface Latitude NAD83 ND State Plane',
#   'api': '33-053-04069'},
#  {'name': "Ash Federal 5300 11-18T Footages 800 F N L 350 F IQtr-Qtr W L LOT1 I Section 18 I Township 153 N 'Range 100 w Field Baker 'Pool Bakken lCounty McKenzie Name of Contractor(s)",
#   'api': '33-053-04211'},
#  {'name': '24-HOUR PRODUCTION RATE Atlanta 14-6H Before After Footages IQtr-Qtr I Section I Township I Range 495 F N L 1485 F W L NENW 6 153 N 101 w Oil 201 Bbls Oil 161 Water 346 Bbls Water 268 Field I Pool I County Baker Bakken Williams Gas 151 MCF Gas 180 Name of Contractor(s)',
#   'api': '33-105-02719'},
#  {'name': 'Atlanta 13-6H Footages IQtr-Qtr I Section 495 F N L 1440 FW L NENW 6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'api': '33-105-0272'},
#  {'name': 'Atlanta 12-6H Footages I Qtr-Qtr I Section 495 F N L 1395 F W L NENW 6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'api': '33-105-02721'},
#  {'name': 'Atlanta 11-6H Footages IQtr-Qtr I Section 495 F N L 1350 F W L NENW 6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'api': '33-105-02722'},
#  {'name': 'Atlanta Federal 10-6H Footages IQtr-Qtr I Section 495 F N L 1305 F W L NENW 6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'api': '33-105-02723'},
#  {'name': "24-HOUR PRODUCTION RATE Atlanta Federal 9-6H Before After Oil 245 Bbls Oil 414 Water 169 Bbls Water 334 Footages IQtr-Qtr I Section I Township I Range 495 F N L 1260 F W L NENW 6 153 N 101 w Gas 186 MCF Gas 321 Field 'Pool 'County Baker Bakken Williams Name of Contractor(s)",
#   'api': '33-105-02724'},
#  {'name': 'Atlanta Federal 8-6H Footages IQtr-Qtr I Section 495 F N L 970 F W L NWNW 6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'api': '33-105-02725'},
#  {'name': 'Atlanta Federal 7-6H Footages IQtr-Qtr I Section 495 F N L 925 F W L NWNW 6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'api': '33-105-02726'},
#  {'name': 'Atlanta Federal 6-6H Atlanta 14 Well Eco Pad',
#   'api': '33-105-02727'},
#  {'name': "Atlanta Federal 6-6H Footages IQtr-Qtr 'Section 495 F N L 880 F W L NWNW 6 Field I Pool Baker Bakken Name of Contractor(s)",
#   'api': '33-105-02728'},
#  {'name': 'Atlanta 4-6H Footages IQtr-Qtr I Section 495 F N L 635 F W L NWNW 6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'api': '33-105-02729'},
#  {'name': 'Atlanta 3-6H Footages IQtr-Qtr I Section 495 F N L 590 F W L NWNW 6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'api': '33-105-0273'},
#  {'name': 'Atlanta 2-6H Footages IQtr-Qtr I Section 495 F N L 545 F W L NWNW 6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'api': '33-105-02731'},
#  {'name': "Atlanta 1-6H Footages lQtr-Qtr 'Section 495 F N L 500 F W L NWNW 6 Field I Pool Baker Bakken Name of Contractor(s)",
#   'api': '33-105-02732'},
#  {'name': 'Cc lumbus Federal 1-16H Op1irator Cc ntinental Resources, Inc',
#   'api': '33-053-04852'},
#  {'name': 'Tallahassee 3-16H', 'api': None},
#  {'name': 'Tallahassee 2-16H', 'api': None},
#  {'name': 'Cc1lumbus Federal 2-16H Op1irator Ccintinental Resources Inc.',
#   'api': None},
#  {'name': 'Columbus Federal 3-16H', 'api': None},
#  {'name': '24-HOUR PRODUCTION RATE Colville 5301 44-12T Before After Footages IQtr-Qtr I Sect ion I Townsh ip I Range 250 F s L 950 F E L SESE 12 153 N 101 w Oil Bbls Oil Water Bbls Water Field I Pool I County Baker Bakken McKenzie Gas MCF Gas Name of Contractor (s)',
#   'api': '33-053-04981'},
#  {'name': 'AP I#: Latitude: Longitude: Datum: Field: Bak er County : McKenz ie State: North Dak ota RKB Height: Tie-in Survey s Provided By Mesa West Directional SE SW Sec 31 T153N R100W NAD83 Rig Contractor & Rig #: Nabors B21 Directi onal Survey Certification Oasis Petrol eum North America LLC Lewis Federal 5300 21-31 6B 2132 2157 33-053-05845 Mesa West Job #: S19062 48˚ 01\' 54.15 N 103˚ 36\' 011.18" W Well Surface Hole Location (SHL): GL Elevation: 147 ft. to 3288 ft. M D (dd/mm/yyy y) 15/02/2019 Date Signed MWD Sur veyor Name: John W oloshyn',
#   'api': '33-053-05845'},
#  {'name': 'Lewis Federal 5300 21-31 5B API #: 33-053-05849 WELL FILE #: 28194 SURFACE LOCATION: 2,552\' FNL & 259\' FWL Lot 2 Section 31, T153N, R100W FIELD/ OBJECTIVE: Baker Field / Middle Bakken COUNTY, STATE: McKenzie County, North Dakota RESERVATION: N/A BASIN: Williston Basin WELL TYPE: Horizontal Development ELEVATION: GL: 2,132\' KB: 2,157\' SPUD DATE: January 30, 2019 RE-ENTRY DATES: Vertical: April 16, 2018 BOTTOM HOLE LOCATION: 111.70 S & 10,097.57\' E of surface location or approx. 2,616.3\' FNL & 169\' FEL, NE SE Sec. 32, T153N, R100W CLOSURE COORDINATES: Closure Azimuth: 90.63° Closure Distance: 10,098.18\' TOTAL DEPTH / DATE: 20,860\' on May 03, 2019 95% within target interval TOTAL DRILLING DAYS: 17 days PUMP INFO: Stroke length - 12 Liner Inner Diameter - 5.0" COMPANY MEN: Ian Anderson',
#   'api': '33-053-05849'},
#  {'name': "Wade Federal 5300 31-30 11T Footages . ·1atr-Qtr I Section 1955 F s L 350 F W L LOT3 30 Field 'Pool Baker Bakken . Name of Contractor(s)",
#   'api': '33-053-05906'},
#  {'name': 'Chalmers 5301 44-24 2TR Footages IQtr-Qtr I Section I Township range 959 F S L 245 F E L SESE 24 153 N 101 w Field I Pool I County Baker Bakken McKenzie Name of Contractor(s)',
#   'api': '33-053-05924'},
#  {'name': 'Wade Federal 5300 41-30 4T', 'api': '33-053-05943'},
#  {'name': 'Wade Federal 5300 41-30 6B', 'api': '33-053-05995'},
#  {'name': '24-HOUR PRODUCTION RATE Chalmers 5301 44-24 3BR Before After Footages IQtr-Qtr I Section I Township I Range 926 F s L 245 F E L SESE 24 153 N 101 w Oil Bbls Oil Water Bbls Water Field I Pool I County Baker Bakken McKenzie Gas MCF Gas Name of Contractor(s)',
#   'api': '33-053-0601'},
#  {'name': '24-HOUR PRODUCTION RA TE Chalmers 5301 44-24 4T2R Before After Footages IQtr-Qtr I Section I Township I Range 877 F s L 245 F E L SESE 24 153 N 101 w Oil Bbls Oil Water Bbls Water Field I Pool I County Baker Bakken McKenzie Gas MCF Gas Name of Contractor(s)',
#   'api': '33-053-06011'},
#  {'name': '0 Deepened Well D Other: N Rf:.<.;,EIVEO o ND Oil & G5 ~ Ni ~ Spacing Unit Description !Well File No. 28601 D Extended Horizontal Leg Chalmers Wade Federal 5301 44-2412TXR Sec. 19/20/29/30 T153N R101W"',
#   'api': '33-053-06012'},
#  {'name': '24-HOUR PRODUCTION RATE Chalmers 5300 21-19 ST Before After Footages · IQtr-Qtr I Section !Townsh ip I Range 2127 F N L 327 F W L LOT2 19 153 N 100 w Oil Bbls Oil Water Bbls Water Field I Pool I County Baker Bakken McKenzie Gas MCF Gas Name of Contractor(s)',
#   'api': '33-053-06018'},
#  {'name': 'Chalmers 5300 21-19 ST', 'api': '33-053-06021'},
#  {'name': 'Chalmers 5300 21-19 10T Footages IQtr-Qtr I Section . !Township I Range 2292 F N L 326 F W L LOT2 19 153 N 100 w Field I Pool I County Baker Bakken McKenzie Name of Contractor(s)',
#   'api': '33-053-06022'},
#  {'name': 'CHALMERS 5300 21-19 98', 'api': '33-053-06023'},
#  {'name': 'Chalmers 5300 21-19 11 B Received FEB 1 2 2016 !Well File No. 28649 ND Oil & Gas Division D Drilling Prognosis D Spill Report D Shooting D D D D D Redrilling or Repair Casing or Liner Plug Well Supplemental History Temporarily Abandon D Acidizing D Fracture Treatment 0 Change Production Method D Reclamat ion D Other Well is now on pump 24-HOUR PRODUCTION RATE Before After Footages IQtr-Qtr , !Section !Township _ I Range 2325 F N L 327 F W L LOT2 .· 19 153 N . 100 w Oil Bbls Oil Water Bbls Water Field I Pool I County Baker Bakken McKenzie Gas MCF Gas Name of Contractor(s )',
#   'api': '33-053-06024'},
#  {'name': 'KLINE FEDERAL 5300 41-18 9T', 'api': None},
#  {'name': "Location: E levation: KB: 2,082' Formation/ Zone Kibbey Lime 8,382' -6,300' 183' 2,368' Charles Salt 8,565' -6,483' 642' 2,185' Base Last Salt 9,207' -7,125' 223' 1,543' Mission Canyon 9,430' -7,348' 567' 1,320' Lodgepole 9,997' -7,915' 708' 753' False Bakken 10,705' -8,623' 7' 45' Upper Bakken Shale 10,712' -8,630' 18' 38' Middle Bakken 10,730' -8,648' 40' 20' Control Well McKenzie Co., ND Oasis Petroleum Kline Federal 5300 41-18 11T2 SW SW Sec. 18 T153N, R100W E st. T VD Approximately 25 ft South MSL Datum T hickness Dist to target KB: 2,082' 8,384 -6,302' 172' 2,361' 8,556 -6,474' 650' 2,189' 9,206 -7,124' 222' 1,539' 9,428 -7,346' 547' 1,317' 9,975 -7,893' 729' 770' 10,704 -8,622' 9' 41' 10,713 -8,631' 17' 32' 10,730 -8,648' 27' 15' Upper Bakken Shale Middle Bakken Kibbey Lime Formation/Zone Approximately 50 feet South MSL Datum E levation: McKenzie Co., ND Lodgepole Charles Salt Mission Canyon Base Last Salt False Bakken Control Well T hickness Dist to targetE st. T VD Oasis Petroleum Kline Federal 5300 41-18 12TX SW SW Sec. 18 T153N, R100W",
#   'api': None},
#  {'name': "24-HOUR PRODUCTION RATE Kline Federal 5300 41-18 13T2X Before After Footages IQtr-Qtr I Section · ITownsh_ip 'Range . _ 401 F s L 237 F w L LOT4 18 . · 153 N 100 w Oil Bbls Oil Water Bbls Water Field I Pool I County Baker Bakken McKenzie Gas MCF Gas Name of Contractor (s)",
#   'api': '33-053-06028'},
#  {'name': "24-HOUR PRODUCTION RATE Kline Federal 5300 41-18 14BX Before After Footages IQtr-Qtr 1$ectiori · !Township range . 368 F s L 237 F w L .LOT4 .·. ·18 .. • 1.53 N 100 w Oil Bbls. Oil Bbls Water . Bbls . Water Bbls Field IPool · · ICountY ' · Baker Bakken McKenzie Ga5 · MCF Gas MCF Name of Contractor(s)",
#   'api': None},
#  {'name': "Kline Federal 5300 41-18 12TX Footages ·IQtr-Qtr · !Section r0W1'.1Ship I Range 434 F s L 237 F w L LOT4 . ·. 18 . 163 N 100 w Field I Pool ·• -icourity . Baker Bakken ·. McKenzie . , .. ' Name of Contractor(s ) ··, . ..",
#   'api': None},
#  {'name': 'D Deepened Well D Other: Spacing Unit Description D Extended Horizontal Leg Wade Federal 5300 41-30 9B Sec. 29/30/31/32 T153N R100W',
#   'api': None},
#  {'name': 'Kline Federal 5300 31-18 8B', 'api': '33-053-00605'},
#  {'name': 'KLINE FEDERAL 5300 31-18 7T', 'api': '33-053-06056'},
#  {'name': "Kline Federal 5300 31-18 6B D D D D D D D RE E I ED FEB 0 3 2017 ND Oil & Gas Div. Drilling Prognosis D Redrilling or Repair D Casing or Liner D Plug Well D Supplemental History 0 Temporarily Abandon D IWell File No. 28756 Spill Report Shooting Acidizing Fracture Treatment Change Production Method Reclamation Other Well is now on pump 24-HOUR PRODUCTION RATE Before After Footages 'Qtr-Qtr 'Section 'Township 'Range 2457 F s L · 238 F W L LOT3 18 153 N 100 w Oil Bbls Oil Water Bbls Water Field 'Pool 'County Baker Bakken McKenzie Name of Contractor(s)",
#   'api': '33-053-06057'},
#  {'name': "Wade Federal 5300 21-30 12T D D D D D D Received FEB 1 2 2016 !JD OH & Gas Divi~ion Drilling Prognosis D Redrilling or Repair D Casing or Liner D Plug Well D Supplemental History 0 Temporarily Abandon D IWell File No. 28976 Spill Report Shooting Acid izing Fracture Treatment Change Production Method Reclamation D Other Well is now on pump 24-HOUR PRODUCTION RATE Before After Footages 'Qtr-Qtr 'Section rownship 'Range 1640 F N L 270 F W L · LOT2 30 153 N 100 w Oil BQls Oil Water Bbls Water Field I Pool I County Baker Bakken McKenzie Gas MCF Gas .. Name of Contractor(s)",
#   'api': '33-053-06129'},
#  {'name': 'WADE FEDERAL 5300 21-30 13B', 'api': '33-053-06131'},
#  {'name': 'Kline Federal 5300 11-18 5B', 'api': '33-053-06223'},
#  {'name': 'Kline Federal 5300 11-18 3T', 'api': '33-053-06225'},
#  {'name': 'Gramma Federal 5300 41-3112B Footages 647 F s L 320 F w IQtr-Qtr L LOT4 I Section . 31 rownship 153 N I Range . 100 w . Field Baker I Pool Bakken I County McKenzie Name of Contractor(s)',
#   'api': '33-053-06231'},
#  {'name': 'Qtr-Qtr Section Township Range County ~G~RA=....::.:.M~M~A~F~E~D~E~RA~L~53~0~0 ~4~1-~31..:.....;.;13~T-1=-~~~~~~..__~~L~O~T~4~___,_~~31.:___,_-15~3~.__~~1~00;.;....a.__',
#   'api': '33-053-06232'},
#  {'name': 'Kline Federal 5300 11-18 2B Footages IQtr-Qtr ISect~o~ !Township range 960 F N L 318 F W L Lot 1 153 N 100 w Field I Pool I County Baker Bakken McKenzie Name of Contractor(s)',
#   'api': '33-053-06243'},
#  {'name': '& No. API # County & State SDI Job # Rig Survey Date I, , having personal knowledge of all the facts, hereby 0 feet to a 2743 Seth M. Burstad Rockies Region Well Planner Scientific Drilling - Rocky Mountain District Survey Certification 7327 West Barton Road Casper, WY 82604 Seth M. Burstad certify that the attached directional survey run from a measured depth of measured depth of feet is true and correct as determined from a ll available records. Date 22-Jan-2019 Nabors B21 Lewis Federal 5300 11-31 3B McKenzie County, ND Oasis Petroleum Signature 22-Jan-2019 33-053-06548 OP.05419',
#   'api': '33-053-06548'},
#  {'name': '& No. API # County & State SDI Job # Rig Survey Date I, , having personal knowledge of all the facts, hereby 0 feet to a 20870 Seth M. Burstad Rockies Region Well Planner Scientific Drilling - Rocky Mountain District Nabors B21 Lewis Federal 5300 11-31 2B McKenzie County, ND Oasis Petroleum Signature 12-Feb-2019 33-053-06549 OP.015962 Date 14-Feb-2019 Survey Certification 7327 West Barton Road Casper, WY 82604 Seth M. Burstad certify that the attached directional survey run from a measured depth of measured depth of feet is true and correct as determined from all available records.',
#   'api': '33-053-06549'},
#  {'name': 'KLINE FEDERAL 5300 31-18 15T', 'api': '33-053-06755'},
#  {'name': '& No. API # County & State SDI Job # Rig Survey Date I, , having personal knowledge of all the facts, hereby 0 feet to a 16577 Seth M. Burstad Rockies Region Well Planner Scientific Drilling - Rocky Mountain District Survey Certification 7327 West Barton Road Casper, WY 82604 Seth M. Burstad certify that the attached directional survey run from a measured depth of measured depth of feet is true and correct as determined from a ll available records. Date 14-Mar-2019 Nabors B21 Lewis Federal 5300 11-31 4BR OH McKenzie County, ND Oasis Petroleum Signature 14-Mar-2019 33-053-08946 OP.016663',
#   'api': '33-053-08946'},
#  {'name': 'BUCK SHOT SWD 5300 31-31', 'api': '33-053-90244'},
#  {'name': "Atlanta #1 SWD Footages IQtr-Qtr I Section !Township !Range 260 F N L 432 F W L NWNW 6 153 N 101 W Field 'Pool 'County Baker Dakota Williams Name of Contractor(s)",
#   'api': None},
#  {'name': 'Carson SWD 5301 12-24', 'api': None}]

# %%
print(f"Found URLs for {sum(1 for well in wells if well['url'])} out of {len(wells)} wells")
# Out:
# Found URLs for 59 out of 71 wells

# %%
################################################
# STEP 2: Extract well details from each well page
# Fields: api_no, well_name, operator, county, well_status, well_type, closest_city, oil_bbl, gas_mcf
# Run STEP 1 first (defines session and populates wells with url).
# Page: section.meta_info (Well Summary), table.skinny (Well Details), p.block_stat (Barrels of Oil / MCF of Gas)
################################################
import re
from bs4 import BeautifulSoup

HEADERS = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"}

def _parse_number(s: str) -> int | None:
    if not s or "members only" in (s or "").lower():
        return None
    m = re.match(r"\s*([\d,.]+)\s*([kKmM]?)\s*$", (s or "").strip())
    if not m:
        return None
    val = float(m.group(1).replace(",", ""))
    suf = (m.group(2) or "").lower()
    if suf == "k": val *= 1_000
    if suf == "m": val *= 1_000_000
    return int(val)

def _text(elem) -> str | None:
    if elem is None:
        return None
    t = elem.get_text(strip=True)
    return t if t and "members only" not in t.lower() else None

def scrape_well_detail(url: str) -> dict:
    """Fetch well detail page; return api_no, well_name, operator, county, well_status, well_type, closest_city, oil_bbl, gas_mcf."""
    r = session.get(url, headers=HEADERS)
    soup = BeautifulSoup(r.text, "html.parser")
    out = {"api_no": None, "well_name": None, "operator": None, "county": None, "well_status": None, "well_type": None, "closest_city": None, "oil_bbl": None, "gas_mcf": None, "production_dates_on_file": None}

    meta = soup.select_one("section.meta_info")
    if meta:
        for div in meta.select("div"):
            label = div.get_text(" ", strip=True).split(":")[0].strip()
            span = div.select_one("span.detail_point")
            if not span:
                continue
            val = (span.find("a") or span).get_text(strip=True)
            if "Well Name" in label or label == "Well Name":
                out["well_name"] = val
            elif "API #" in label or label == "API #":
                out["api_no"] = val
            elif "Operator" in label or label == "Operator":
                out["operator"] = val
            elif "County" in label or label == "County":
                out["county"] = val
            elif "Production Dates on File" in label:
                out["production_dates_on_file"] = val

    table = soup.select_one("table.skinny")
    if table:
        for tr in table.select("tr"):
            for th in tr.select("th"):
                key = th.get_text(strip=True)
                td = th.find_next_sibling("td")
                val = _text(td) if td else None
                if key == "Well Status":
                    out["well_status"] = val
                elif key == "Well Type":
                    out["well_type"] = val
                elif key == "Closest City":
                    out["closest_city"] = val
                elif key == "County" and out["county"] is None:
                    out["county"] = val
                elif key == "API No." and out["api_no"] is None:
                    out["api_no"] = val
                elif key == "Well Name" and out["well_name"] is None:
                    out["well_name"] = val
                elif key == "Operator" and out["operator"] is None:
                    out["operator"] = val

    for p in soup.select("p.block_stat"):
        num_span = p.select_one("span.dropcap")
        if not num_span:
            continue
        num = _parse_number(num_span.get_text(strip=True))
        num_span.decompose()
        desc = p.get_text(" ", strip=True).lower()
        if "oil" in desc and ("barrel" in desc or "bbl" in desc):
            out["oil_bbl"] = num
        elif "gas" in desc and ("mcf" in desc or "mmcf" in desc):
            out["gas_mcf"] = num

    return out

for well in wells:
    url = well.get("url")
    if url:
        data = scrape_well_detail(url)
        well["api_no"] = data["api_no"]
        well["well_name"] = data["well_name"]
        well["operator"] = data["operator"]
        well["county"] = data["county"]
        well["well_status"] = data["well_status"]
        well["well_type"] = data["well_type"]
        well["closest_city"] = data["closest_city"]
        well["oil_bbl"] = data["oil_bbl"]
        well["gas_mcf"] = data["gas_mcf"]
        well["production_dates_on_file"] = data["production_dates_on_file"]
    else:
        well["api_no"] = well.get("api")
        well["well_name"] = well.get("name")
        well["operator"] = None
        well["county"] = well.get("county")  # keep CSV county when no URL
        well["well_status"] = well["well_type"] = well["closest_city"] = None
        well["oil_bbl"] = well["gas_mcf"] = well["production_dates_on_file"] = None
# Out:
# [{'api': None,
#   'api_no': '33-053-02102',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 518,
#   'name': 'Basic Game & Fish 34-3',
#   'oil_bbl': 518,
#   'operator': 'Rim Operating, Inc.',
#   'production_dates_on_file': 'January 1986 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/basic-game-and-fish-34-3/33-053-02102',
#   'well_name': 'Basic Game And Fish 34-3',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': None,
#   'api_no': '33-053-02148',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': None,
#   'name': 'Corps of En ineers 31-10',
#   'oil_bbl': 64,
#   'operator': 'Rim Operating, Inc.',
#   'production_dates_on_file': 'November 1986 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/corps-of-engineers-31-10/33-053-02148',
#   'well_name': 'Corps Of Engineers 31-10',
#   'well_status': 'Plugged and Abandoned',
#   'well_type': 'Oil & Gas'},
#  {'api': None,
#   'api_no': '33-053-02556',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 537,
#   'name': 'Lewis & Clark 2-4H',
#   'oil_bbl': 537,
#   'operator': 'Rim Operating, Inc.',
#   'production_dates_on_file': 'June 2003 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/lewis-and-clark-2-4h/33-053-02556',
#   'well_name': 'Lewis And Clark 2-4H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'}]

# %%
import pprint
pprint.pprint(wells)
# Out:
# [{'api': None,
#   'api_no': '33-053-02102',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 518,
#   'name': 'Basic Game & Fish 34-3',
#   'oil_bbl': 518,
#   'operator': 'Rim Operating, Inc.',
#   'production_dates_on_file': 'January 1986 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/basic-game-and-fish-34-3/33-053-02102',
#   'well_name': 'Basic Game And Fish 34-3',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': None,
#   'api_no': '33-053-02148',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': None,
#   'name': 'Corps of En ineers 31-10',
#   'oil_bbl': 64,
#   'operator': 'Rim Operating, Inc.',
#   'production_dates_on_file': 'November 1986 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/corps-of-engineers-31-10/33-053-02148',
#   'well_name': 'Corps Of Engineers 31-10',
#   'well_status': 'Plugged and Abandoned',
#   'well_type': 'Oil & Gas'},
#  {'api': None,
#   'api_no': '33-053-02556',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 537,
#   'name': 'Lewis & Clark 2-4H',
#   'oil_bbl': 537,
#   'operator': 'Rim Operating, Inc.',
#   'production_dates_on_file': 'June 2003 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/lewis-and-clark-2-4h/33-053-02556',
#   'well_name': 'Lewis And Clark 2-4H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': None,
#   'api_no': None,
#   'closest_city': None,
#   'county': None,
#   'gas_mcf': None,
#   'name': 'Field/ Prospect: McKenziel County, NDHarper Oil Company Well '
#           'Information 8 3/4 to 11',
#   'oil_bbl': None,
#   'operator': None,
#   'production_dates_on_file': None,
#   'url': None,
#   'well_name': 'Field/ Prospect: McKenziel County, NDHarper Oil Company Well '
#                'Information 8 3/4 to 11',
#   'well_status': None,
#   'well_type': None},
#  {'api': None,
#   'api_no': None,
#   'closest_city': None,
#   'county': None,
#   'gas_mcf': None,
#   'name': '(see details Footages F L Field Name of Contractor(s)',
#   'oil_bbl': None,
#   'operator': None,
#   'production_dates_on_file': None,
#   'url': None,
#   'well_name': '(see details Footages F L Field Name of Contractor(s)',
#   'well_status': None,
#   'well_type': None},
#  {'api': None,
#   'api_no': None,
#   'closest_city': None,
#   'county': None,
#   'gas_mcf': None,
#   'name': 'Foley Federal 5301 43-12H Original Hole NDIC File No. 20863 '
#           'Location: Section 12-T153N-R101W County/State: McKenzie County, ND '
#           'Surveyed From a Depth of: 2,186’ MD to 12,283’ MD Type of Survey: '
#           'Magnetic MWD Name(s) of MWD Supervisor(s): John Capra / Brandon '
#           'Ramirez The data and calculations for this survey have been checked '
#           'by me and conform to the standards and procedures set forth by '
#           'Professional Directional Ltd. This report represents a true and '
#           'correct Directional Survey of this well based on the original data '
#           'obtained at the well site. The survey was calculated using the '
#           'minimum curvature method. Robert D. Hays / Well Planner',
#   'oil_bbl': None,
#   'operator': None,
#   'production_dates_on_file': None,
#   'url': None,
#   'well_name': 'Foley Federal 5301 43-12H Original Hole NDIC File No. 20863 '
#                'Location: Section 12-T153N-R101W County/State: McKenzie '
#                'County, ND Surveyed From a Depth of: 2,186’ MD to 12,283’ MD '
#                'Type of Survey: Magnetic MWD Name(s) of MWD Supervisor(s): '
#                'John Capra / Brandon Ramirez The data and calculations for '
#                'this survey have been checked by me and conform to the '
#                'standards and procedures set forth by Professional Directional '
#                'Ltd. This report represents a true and correct Directional '
#                'Survey of this well based on the original data obtained at the '
#                'well site. The survey was calculated using the minimum '
#                'curvature method. Robert D. Hays / Well Planner',
#   'well_status': None,
#   'well_type': None},
#  {'api': '33-053-03911',
#   'api_no': '33-053-03911',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 1500,
#   'name': 'and Numbe r 24-HOUR PRODUCTION RA TE (see details) Before After '
#           'Footages L IQtr-Qtr I Section I Township I Range F L F 12 153 N 101 '
#           'w Oil Bbls Oil Water Bbls Water Field I Pool I County Baker Bakken '
#           'McKenzie Gas MCF Gas Name of Contractor(s)',
#   'oil_bbl': 1100,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'September 2013 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/yukon-5301-41-12t/33-053-03911',
#   'well_name': 'Yukon 5301 41-12T',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': None,
#   'api_no': '33-053-03703',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': None,
#   'name': 'DAHL 15-11H',
#   'oil_bbl': None,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'January 2012 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/dahl-federal-15-11h/33-053-03703',
#   'well_name': 'Dahl Federal 15-11H',
#   'well_status': 'Plugged and Abandoned',
#   'well_type': 'Oil & Gas'},
#  {'api': None,
#   'api_no': '33-053-03846',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 3400,
#   'name': 'DAHL FEDERAL 2-15H',
#   'oil_bbl': 1500,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'May 2012 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/dahl-federal-2-15h/33-053-03846',
#   'well_name': 'Dahl Federal 2-15H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-03943',
#   'api_no': '33-053-03943',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 1000,
#   'name': 'Magnum 1-36-25H Footages I Qtr-Qtr I Section 250 FS L 815 F WL SWSW '
#           '38 Field l~ken Baker D Drilling Prognosis IZI Redrilling or Repair '
#           'D casing or Liner D PlugWell 0 Supplemental Hlllllory D Temporarily '
#           'Abandon D Other !Township I Range 153 N 101 w I County McKenzie '
#           "'City DETAILS OF WORK D D D D D D !Well Fie No. 22247 SpRI Report "
#           'Shooting Acidlzlng Fracture Treatment Change Production Method '
#           'Reclamation zu.IOUR PRODUCTION RATE Before After Oil Bbfs Oil Water '
#           "Bbls Water Gas MCF Gas 'State 'Zip Code Bbls Bbls MCF Slawson "
#           'Exploration Company, Inc. (SECI) will perform remedial work on the '
#           'Magnum 1-36-25H well. Attached with this fonn Is the procedure of '
#           'work to be completed and the well bore diagram for your review. '
#           'Company Slawson Exploration Company, Inc.',
#   'oil_bbl': 1400,
#   'operator': 'Enerplus Resources USA Corporation',
#   'production_dates_on_file': 'April 2012 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/magnum-1-36-25h/33-053-03943',
#   'well_name': 'Magnum 1-36-25H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-03944',
#   'api_no': '33-053-03944',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 193,
#   'name': 'MAGNUM 2-36-25H Oper< tor Telephone Number 720-457 -9820 All of '
#           'Sect 36 & 25 T153N R101W Field Slawson Exploration Com an , Inc. '
#           'BAKER Pool Suite 1600 Bakken City State Zip Code Permit Type Denver '
#           'CO 80202 D Wildcat 0 Development D Extension ~-----------_._ ___ '
#           '_._ ________ _._-=~...;,_;;..;...;. ___ '
#           '_=:_...;,_....:....._;_...;,_ _ ___. __ __;,.;_;,...;,_ __ ~ '
#           'LOCATION OF WELL -At Su1face Otr-Qtr I Section !Township I Range '
#           'County 205 F s L 240 F E L SESE 36 153 N 101 w McKenzie -Spud Date '
#           'I Date TD Reached Drilling Contractor and Rig Number I KB Elevation '
#           '(Ft) Graded Elevation (Ft) 3/1812012 4/27/2012 Nabors #419 2177 '
#           '2156 -Type of Electric and Other Logs Run (See Instructions) Tripl '
#           '1e Combo - OIL, CNL, COL with GR to surface CBL/GR/CCL CASING & '
#           'TUBULARS RECORD (Report all strin! s set in well) w Surfac Vertie '
#           'Latera ~II Bore ;e Hole 11 Hole 11 Type Surface Intermediate Liner '
#           'String Size (Inch) 9 5/8 7 4 1/2 Top Set Depth Set (MD Ft) (MD Ft) '
#           '0 2168 0 11104 9082 20705 Hole Size Weight Anchor Set Packer Set '
#           'Sacks Top of (Inch) (Lbs/Ft) (MD Ft) (MD Ft) Cement Cement 13 1/2 '
#           '36 835 8 3/4 29 & 32 1025 2200 6 11.6 9082 PERFORATION & OPEN HOLE '
#           'INTERVALS - Well Bore TD Open Hole/Perforated Kick-off Top of Weill '
#           'Bore Drillers Depth Completion Interval (MD.Ft) Point Casing Type '
#           'Window (MD Ft) Top Bottom (MD Ft) (MD Ft) -Latera !1 20728 Other '
#           '11104 20705 10282 11104 -- ~ ------ PRODUCTION Curren Producing '
#           'Open Hole or Perforated lnterval(s )',
#   'oil_bbl': 296,
#   'operator': 'Enerplus Resources USA Corporation',
#   'production_dates_on_file': 'February 2013 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/magnum-2-36-25h/33-053-03944',
#   'well_name': 'Magnum 2-36-25H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-04069',
#   'api_no': '33-053-04069',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': None,
#   'name': "McKenzie County, ND County/State W 103 36' 16.88040 Surface "
#           'Longitude Nabors 419 Rig Contractor/ Name 0 to 9319 ft Measurements '
#           'While Drilling (MWD) ft Jeromy Haggerty Slawson Company ND-SLW-0038 '
#           'Job Number N 48 1\' 29.71560" Surface Latitude NAD83 ND State Plane',
#   'oil_bbl': None,
#   'operator': 'Enerplus Resources USA Corporation',
#   'production_dates_on_file': 'July 2012 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/magnum-3-36-25h/33-053-04069',
#   'well_name': 'Magnum 3-36-25H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-04211',
#   'api_no': '33-053-04211',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 186,
#   'name': 'Ash Federal 5300 11-18T Footages 800 F N L 350 F IQtr-Qtr W L LOT1 '
#           "I Section 18 I Township 153 N 'Range 100 w Field Baker 'Pool Bakken "
#           'lCounty McKenzie Name of Contractor(s)',
#   'oil_bbl': 256,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'November 2012 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/ash-federal-5300-11-18t/33-053-04211',
#   'well_name': 'Ash Federal 5300 11-18T',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-105-02719',
#   'api_no': '33-105-02719',
#   'closest_city': 'Williston',
#   'county': 'Williams County, ND',
#   'gas_mcf': 872,
#   'name': '24-HOUR PRODUCTION RATE Atlanta 14-6H Before After Footages '
#           'IQtr-Qtr I Section I Township I Range 495 F N L 1485 F W L NENW 6 '
#           '153 N 101 w Oil 201 Bbls Oil 161 Water 346 Bbls Water 268 Field I '
#           'Pool I County Baker Bakken Williams Gas 151 MCF Gas 180 Name of '
#           'Contractor(s)',
#   'oil_bbl': 592,
#   'operator': 'Continental Resources, Inc.',
#   'production_dates_on_file': 'February 2014 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-14-6h/33-105-02719',
#   'well_name': 'Atlanta 14-6H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-105-0272',
#   'api_no': '33-105-0272',
#   'closest_city': None,
#   'county': None,
#   'gas_mcf': None,
#   'name': 'Atlanta 13-6H Footages IQtr-Qtr I Section 495 F N L 1440 FW L NENW '
#           '6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'oil_bbl': None,
#   'operator': None,
#   'production_dates_on_file': None,
#   'url': None,
#   'well_name': 'Atlanta 13-6H Footages IQtr-Qtr I Section 495 F N L 1440 FW L '
#                'NENW 6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'well_status': None,
#   'well_type': None},
#  {'api': '33-105-02721',
#   'api_no': '33-105-02721',
#   'closest_city': 'Williston',
#   'county': 'Williams County, ND',
#   'gas_mcf': None,
#   'name': 'Atlanta 12-6H Footages I Qtr-Qtr I Section 495 F N L 1395 F W L '
#           'NENW 6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'oil_bbl': None,
#   'operator': 'Continental Resources, Inc.',
#   'production_dates_on_file': 'February 2014 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-12-6h/33-105-02721',
#   'well_name': 'Atlanta 12-6H',
#   'well_status': 'Inactive',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-105-02722',
#   'api_no': '33-105-02722',
#   'closest_city': 'Williston',
#   'county': 'Williams County, ND',
#   'gas_mcf': 843,
#   'name': 'Atlanta 11-6H Footages IQtr-Qtr I Section 495 F N L 1350 F W L NENW '
#           '6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'oil_bbl': 565,
#   'operator': 'Continental Resources, Inc.',
#   'production_dates_on_file': 'February 2014 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-11-6h/33-105-02722',
#   'well_name': 'Atlanta 11-6H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-105-02723',
#   'api_no': '33-105-02723',
#   'closest_city': 'Williston',
#   'county': 'Williams County, ND',
#   'gas_mcf': 666,
#   'name': 'Atlanta Federal 10-6H Footages IQtr-Qtr I Section 495 F N L 1305 F '
#           'W L NENW 6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'oil_bbl': 387,
#   'operator': 'Continental Resources, Inc.',
#   'production_dates_on_file': 'February 2014 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-federal-10-6h/33-105-02723',
#   'well_name': 'Atlanta Federal 10-6H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-105-02724',
#   'api_no': '33-105-02724',
#   'closest_city': 'Williston',
#   'county': 'Williams County, ND',
#   'gas_mcf': None,
#   'name': '24-HOUR PRODUCTION RATE Atlanta Federal 9-6H Before After Oil 245 '
#           'Bbls Oil 414 Water 169 Bbls Water 334 Footages IQtr-Qtr I Section I '
#           'Township I Range 495 F N L 1260 F W L NENW 6 153 N 101 w Gas 186 '
#           "MCF Gas 321 Field 'Pool 'County Baker Bakken Williams Name of "
#           'Contractor(s)',
#   'oil_bbl': None,
#   'operator': 'Continental Resources, Inc.',
#   'production_dates_on_file': 'February 2014 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-federal-9-6h/33-105-02724',
#   'well_name': 'Atlanta Federal 9-6H',
#   'well_status': 'Inactive',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-105-02725',
#   'api_no': '33-105-02725',
#   'closest_city': 'Williston',
#   'county': 'Williams County, ND',
#   'gas_mcf': 493,
#   'name': 'Atlanta Federal 8-6H Footages IQtr-Qtr I Section 495 F N L 970 F W '
#           'L NWNW 6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'oil_bbl': 229,
#   'operator': 'Continental Resources, Inc.',
#   'production_dates_on_file': 'February 2014 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-federal-8-6h/33-105-02725',
#   'well_name': 'Atlanta Federal 8-6H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-105-02726',
#   'api_no': '33-105-02726',
#   'closest_city': 'Williston',
#   'county': 'Williams County, ND',
#   'gas_mcf': 1000,
#   'name': 'Atlanta Federal 7-6H Footages IQtr-Qtr I Section 495 F N L 925 F W '
#           'L NWNW 6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'oil_bbl': 787,
#   'operator': 'Continental Resources, Inc.',
#   'production_dates_on_file': 'February 2014 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-federal-7-6h/33-105-02726',
#   'well_name': 'Atlanta Federal 7-6H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-105-02727',
#   'api_no': '33-105-02727',
#   'closest_city': 'Williston',
#   'county': 'Williams County, ND',
#   'gas_mcf': 609,
#   'name': 'Atlanta Federal 6-6H Atlanta 14 Well Eco Pad',
#   'oil_bbl': 339,
#   'operator': 'Continental Resources, Inc.',
#   'production_dates_on_file': 'February 2014 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-federal-6-6h/33-105-02727',
#   'well_name': 'Atlanta Federal 6-6H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-105-02728',
#   'api_no': '33-105-02728',
#   'closest_city': 'Williston',
#   'county': 'Williams County, ND',
#   'gas_mcf': 794,
#   'name': "Atlanta Federal 6-6H Footages IQtr-Qtr 'Section 495 F N L 880 F W L "
#           'NWNW 6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'oil_bbl': 520,
#   'operator': 'Continental Resources, Inc.',
#   'production_dates_on_file': 'February 2014 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-federal-5-6h/33-105-02728',
#   'well_name': 'Atlanta Federal 5-6H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-105-02729',
#   'api_no': '33-105-02729',
#   'closest_city': 'Williston',
#   'county': 'Williams County, ND',
#   'gas_mcf': 449,
#   'name': 'Atlanta 4-6H Footages IQtr-Qtr I Section 495 F N L 635 F W L NWNW 6 '
#           'Field I Pool Baker Bakken Name of Contractor(s)',
#   'oil_bbl': 173,
#   'operator': 'Continental Resources, Inc.',
#   'production_dates_on_file': 'February 2014 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-4-6h/33-105-02729',
#   'well_name': 'Atlanta 4-6H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-105-0273',
#   'api_no': '33-105-0273',
#   'closest_city': None,
#   'county': None,
#   'gas_mcf': None,
#   'name': 'Atlanta 3-6H Footages IQtr-Qtr I Section 495 F N L 590 F W L NWNW 6 '
#           'Field I Pool Baker Bakken Name of Contractor(s)',
#   'oil_bbl': None,
#   'operator': None,
#   'production_dates_on_file': None,
#   'url': None,
#   'well_name': 'Atlanta 3-6H Footages IQtr-Qtr I Section 495 F N L 590 F W L '
#                'NWNW 6 Field I Pool Baker Bakken Name of Contractor(s)',
#   'well_status': None,
#   'well_type': None},
#  {'api': '33-105-02731',
#   'api_no': '33-105-02731',
#   'closest_city': 'Williston',
#   'county': 'Williams County, ND',
#   'gas_mcf': 351,
#   'name': 'Atlanta 2-6H Footages IQtr-Qtr I Section 495 F N L 545 F W L NWNW 6 '
#           'Field I Pool Baker Bakken Name of Contractor(s)',
#   'oil_bbl': 84,
#   'operator': 'Continental Resources, Inc.',
#   'production_dates_on_file': 'February 2014 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-2-6h/33-105-02731',
#   'well_name': 'Atlanta 2-6H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-105-02732',
#   'api_no': '33-105-02732',
#   'closest_city': 'Williston',
#   'county': 'Williams County, ND',
#   'gas_mcf': None,
#   'name': "Atlanta 1-6H Footages lQtr-Qtr 'Section 495 F N L 500 F W L NWNW 6 "
#           'Field I Pool Baker Bakken Name of Contractor(s)',
#   'oil_bbl': None,
#   'operator': 'Continental Resources, Inc.',
#   'production_dates_on_file': 'March 2013 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/williams-county/wells/atlanta-1-6h/33-105-02732',
#   'well_name': 'Atlanta 1-6H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-04852',
#   'api_no': '33-053-04852',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 2500,
#   'name': 'Cc lumbus Federal 1-16H Op1irator Cc ntinental Resources, Inc',
#   'oil_bbl': 1100,
#   'operator': 'Continental Resources, Inc.',
#   'production_dates_on_file': 'July 2013 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/columbus-federal-1-16h/33-053-04852',
#   'well_name': 'Columbus Federal 1-16H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': None,
#   'api_no': '33-053-04853',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 419,
#   'name': 'Tallahassee 3-16H',
#   'oil_bbl': 389,
#   'operator': 'Continental Resources, Inc.',
#   'production_dates_on_file': 'March 2014 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/tallahassee-3-16h/33-053-04853',
#   'well_name': 'Tallahassee 3-16H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': None,
#   'api_no': '33-053-04854',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 1300,
#   'name': 'Tallahassee 2-16H',
#   'oil_bbl': 277,
#   'operator': 'Continental Resources, Inc.',
#   'production_dates_on_file': 'March 2014 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/tallahassee-2-16h/33-053-04854',
#   'well_name': 'Tallahassee 2-16H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': None,
#   'api_no': None,
#   'closest_city': None,
#   'county': None,
#   'gas_mcf': None,
#   'name': 'Cc1lumbus Federal 2-16H Op1irator Ccintinental Resources Inc.',
#   'oil_bbl': None,
#   'operator': None,
#   'production_dates_on_file': None,
#   'url': None,
#   'well_name': 'Cc1lumbus Federal 2-16H Op1irator Ccintinental Resources Inc.',
#   'well_status': None,
#   'well_type': None},
#  {'api': None,
#   'api_no': '33-053-04856',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 702,
#   'name': 'Columbus Federal 3-16H',
#   'oil_bbl': 570,
#   'operator': 'Continental Resources, Inc.',
#   'production_dates_on_file': 'March 2014 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/columbus-federal-3-16h/33-053-04856',
#   'well_name': 'Columbus Federal 3-16H',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-04981',
#   'api_no': '33-053-04981',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 1100,
#   'name': '24-HOUR PRODUCTION RATE Colville 5301 44-12T Before After Footages '
#           'IQtr-Qtr I Sect ion I Townsh ip I Range 250 F s L 950 F E L SESE 12 '
#           '153 N 101 w Oil Bbls Oil Water Bbls Water Field I Pool I County '
#           'Baker Bakken McKenzie Gas MCF Gas Name of Contractor (s)',
#   'oil_bbl': 714,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'September 2013 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/colville-5301-44-12t/33-053-04981',
#   'well_name': 'Colville 5301 44-12T',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-05845',
#   'api_no': '33-053-05845',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 4100,
#   'name': 'AP I#: Latitude: Longitude: Datum: Field: Bak er County : McKenz ie '
#           'State: North Dak ota RKB Height: Tie-in Survey s Provided By Mesa '
#           'West Directional SE SW Sec 31 T153N R100W NAD83 Rig Contractor & '
#           'Rig #: Nabors B21 Directi onal Survey Certification Oasis Petrol '
#           'eum North America LLC Lewis Federal 5300 21-31 6B 2132 2157 '
#           "33-053-05845 Mesa West Job #: S19062 48˚ 01' 54.15 N 103˚ 36' "
#           '011.18" W Well Surface Hole Location (SHL): GL Elevation: 147 ft. '
#           'to 3288 ft. M D (dd/mm/yyy y) 15/02/2019 Date Signed MWD Sur veyor '
#           'Name: John W oloshyn',
#   'oil_bbl': 967,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'September 2019 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/lewis-federal-5300-21-31-6b/33-053-05845',
#   'well_name': 'Lewis Federal 5300 21-31 6B',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-05849',
#   'api_no': '33-053-05849',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 211,
#   'name': 'Lewis Federal 5300 21-31 5B API #: 33-053-05849 WELL FILE #: 28194 '
#           "SURFACE LOCATION: 2,552' FNL & 259' FWL Lot 2 Section 31, T153N, "
#           'R100W FIELD/ OBJECTIVE: Baker Field / Middle Bakken COUNTY, STATE: '
#           'McKenzie County, North Dakota RESERVATION: N/A BASIN: Williston '
#           "Basin WELL TYPE: Horizontal Development ELEVATION: GL: 2,132' KB: "
#           "2,157' SPUD DATE: January 30, 2019 RE-ENTRY DATES: Vertical: April "
#           "16, 2018 BOTTOM HOLE LOCATION: 111.70 S & 10,097.57' E of surface "
#           "location or approx. 2,616.3' FNL & 169' FEL, NE SE Sec. 32, T153N, "
#           'R100W CLOSURE COORDINATES: Closure Azimuth: 90.63° Closure '
#           "Distance: 10,098.18' TOTAL DEPTH / DATE: 20,860' on May 03, 2019 "
#           '95% within target interval TOTAL DRILLING DAYS: 17 days PUMP INFO: '
#           'Stroke length - 12 Liner Inner Diameter - 5.0" COMPANY MEN: Ian '
#           'Anderson',
#   'oil_bbl': 1000,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'September 2019 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/lewis-federal-5300-21-31-5b/33-053-05849',
#   'well_name': 'Lewis Federal 5300 21-31 5B',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-05906',
#   'api_no': '33-053-05906',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 1200,
#   'name': 'Wade Federal 5300 31-30 11T Footages . ·1atr-Qtr I Section 1955 F s '
#           "L 350 F W L LOT3 30 Field 'Pool Baker Bakken . Name of "
#           'Contractor(s)',
#   'oil_bbl': 243,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'May 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/wade-federal-5300-31-30-11t/33-053-05906',
#   'well_name': 'Wade Federal 5300 31-30 11T',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-05924',
#   'api_no': '33-053-05924',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 2500,
#   'name': 'Chalmers 5301 44-24 2TR Footages IQtr-Qtr I Section I Township '
#           'range 959 F S L 245 F E L SESE 24 153 N 101 w Field I Pool I County '
#           'Baker Bakken McKenzie Name of Contractor(s)',
#   'oil_bbl': 275,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'December 2014 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-5301-44-24-2tr/33-053-05924',
#   'well_name': 'Chalmers 5301 44-24 2TR',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-05943',
#   'api_no': '33-053-05943',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 779,
#   'name': 'Wade Federal 5300 41-30 4T',
#   'oil_bbl': 78,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'May 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/wade-federal-5300-41-30-4t/33-053-05943',
#   'well_name': 'Wade Federal 5300 41-30 4T',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-05995',
#   'api_no': '33-053-05995',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 1600,
#   'name': 'Wade Federal 5300 41-30 6B',
#   'oil_bbl': 266,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'May 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/wade-federal-5300-31-30-2b/33-053-05995',
#   'well_name': 'Wade Federal 5300 31-30 2B',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-0601',
#   'api_no': '33-053-0601',
#   'closest_city': None,
#   'county': None,
#   'gas_mcf': None,
#   'name': '24-HOUR PRODUCTION RATE Chalmers 5301 44-24 3BR Before After '
#           'Footages IQtr-Qtr I Section I Township I Range 926 F s L 245 F E L '
#           'SESE 24 153 N 101 w Oil Bbls Oil Water Bbls Water Field I Pool I '
#           'County Baker Bakken McKenzie Gas MCF Gas Name of Contractor(s)',
#   'oil_bbl': None,
#   'operator': None,
#   'production_dates_on_file': None,
#   'url': None,
#   'well_name': '24-HOUR PRODUCTION RATE Chalmers 5301 44-24 3BR Before After '
#                'Footages IQtr-Qtr I Section I Township I Range 926 F s L 245 F '
#                'E L SESE 24 153 N 101 w Oil Bbls Oil Water Bbls Water Field I '
#                'Pool I County Baker Bakken McKenzie Gas MCF Gas Name of '
#                'Contractor(s)',
#   'well_status': None,
#   'well_type': None},
#  {'api': '33-053-06011',
#   'api_no': '33-053-06011',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': None,
#   'name': '24-HOUR PRODUCTION RA TE Chalmers 5301 44-24 4T2R Before After '
#           'Footages IQtr-Qtr I Section I Township I Range 877 F s L 245 F E L '
#           'SESE 24 153 N 101 w Oil Bbls Oil Water Bbls Water Field I Pool I '
#           'County Baker Bakken McKenzie Gas MCF Gas Name of Contractor(s)',
#   'oil_bbl': None,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'December 2014 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-5301-44-24-4t2r/33-053-06011',
#   'well_name': 'Chalmers 5301 44-24 4T2R',
#   'well_status': 'Abandoned',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06012',
#   'api_no': '33-053-06012',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 3600,
#   'name': '0 Deepened Well D Other: N Rf:.<.;,EIVEO o ND Oil & G5 ~ Ni ~ '
#           'Spacing Unit Description !Well File No. 28601 D Extended Horizontal '
#           'Leg Chalmers Wade Federal 5301 44-2412TXR Sec. 19/20/29/30 T153N '
#           'R101W"',
#   'oil_bbl': 540,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'December 2014 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-wade-federal-5301-44-24-12txr/33-053-06012',
#   'well_name': 'Chalmers Wade Federal 5301 44-24 12TXR',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06018',
#   'api_no': '33-053-06018',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 1000,
#   'name': '24-HOUR PRODUCTION RATE Chalmers 5300 21-19 ST Before After '
#           'Footages · IQtr-Qtr I Section !Townsh ip I Range 2127 F N L 327 F W '
#           'L LOT2 19 153 N 100 w Oil Bbls Oil Water Bbls Water Field I Pool I '
#           'County Baker Bakken McKenzie Gas MCF Gas Name of Contractor(s)',
#   'oil_bbl': 396,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'July 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-5300-21-19-5t/33-053-06018',
#   'well_name': 'Chalmers 5300 21-19 5T',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06019',
#   'api_no': '33-053-06019',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 553,
#   'name': 'Chalmers 5300 21-19 6B D Recompletion D Water Supply Well D '
#           'Deepened Well D Other: D Added Horizontal Leg Spacing Unit '
#           'Description Sec. 19/20 T153N R100W',
#   'oil_bbl': 292,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'July 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-5300-21-19-6b/33-053-06019',
#   'well_name': 'Chalmers 5300 21-19 6B',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06021',
#   'api_no': '33-053-06021',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 1500,
#   'name': 'Chalmers 5300 21-19 ST',
#   'oil_bbl': 227,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'July 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-5300-21-19-8t/33-053-06021',
#   'well_name': 'Chalmers 5300 21-19 8T',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06022',
#   'api_no': '33-053-06022',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 1300,
#   'name': 'Chalmers 5300 21-19 10T Footages IQtr-Qtr I Section . !Township I '
#           'Range 2292 F N L 326 F W L LOT2 19 153 N 100 w Field I Pool I '
#           'County Baker Bakken McKenzie Name of Contractor(s)',
#   'oil_bbl': 248,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'May 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-5300-21-19-10t/33-053-06022',
#   'well_name': 'Chalmers 5300 21-19 10T',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06023',
#   'api_no': '33-053-06023',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 1200,
#   'name': 'CHALMERS 5300 21-19 98',
#   'oil_bbl': 321,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'May 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-5300-21-19-9b/33-053-06023',
#   'well_name': 'Chalmers 5300 21-19 9B',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06024',
#   'api_no': '33-053-06024',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 770,
#   'name': 'Chalmers 5300 21-19 11 B Received FEB 1 2 2016 !Well File No. 28649 '
#           'ND Oil & Gas Division D Drilling Prognosis D Spill Report D '
#           'Shooting D D D D D Redrilling or Repair Casing or Liner Plug Well '
#           'Supplemental History Temporarily Abandon D Acidizing D Fracture '
#           'Treatment 0 Change Production Method D Reclamat ion D Other Well is '
#           'now on pump 24-HOUR PRODUCTION RATE Before After Footages IQtr-Qtr '
#           ', !Section !Township _ I Range 2325 F N L 327 F W L LOT2 .· 19 153 '
#           'N . 100 w Oil Bbls Oil Water Bbls Water Field I Pool I County Baker '
#           'Bakken McKenzie Gas MCF Gas Name of Contractor(s )',
#   'oil_bbl': 135,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'May 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/chalmers-5300-21-19-11b/33-053-06024',
#   'well_name': 'Chalmers 5300 21-19 11B',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': None,
#   'api_no': '33-053-06025',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 2600,
#   'name': 'KLINE FEDERAL 5300 41-18 9T',
#   'oil_bbl': 379,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'September 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/kline-federal-5300-41-18-9t/33-053-06025',
#   'well_name': 'Kline Federal 5300 41-18 9T',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': None,
#   'api_no': None,
#   'closest_city': None,
#   'county': None,
#   'gas_mcf': None,
#   'name': "Location: E levation: KB: 2,082' Formation/ Zone Kibbey Lime 8,382' "
#           "-6,300' 183' 2,368' Charles Salt 8,565' -6,483' 642' 2,185' Base "
#           "Last Salt 9,207' -7,125' 223' 1,543' Mission Canyon 9,430' -7,348' "
#           "567' 1,320' Lodgepole 9,997' -7,915' 708' 753' False Bakken 10,705' "
#           "-8,623' 7' 45' Upper Bakken Shale 10,712' -8,630' 18' 38' Middle "
#           "Bakken 10,730' -8,648' 40' 20' Control Well McKenzie Co., ND Oasis "
#           'Petroleum Kline Federal 5300 41-18 11T2 SW SW Sec. 18 T153N, R100W '
#           'E st. T VD Approximately 25 ft South MSL Datum T hickness Dist to '
#           "target KB: 2,082' 8,384 -6,302' 172' 2,361' 8,556 -6,474' 650' "
#           "2,189' 9,206 -7,124' 222' 1,539' 9,428 -7,346' 547' 1,317' 9,975 "
#           "-7,893' 729' 770' 10,704 -8,622' 9' 41' 10,713 -8,631' 17' 32' "
#           "10,730 -8,648' 27' 15' Upper Bakken Shale Middle Bakken Kibbey Lime "
#           'Formation/Zone Approximately 50 feet South MSL Datum E levation: '
#           'McKenzie Co., ND Lodgepole Charles Salt Mission Canyon Base Last '
#           'Salt False Bakken Control Well T hickness Dist to targetE st. T VD '
#           'Oasis Petroleum Kline Federal 5300 41-18 12TX SW SW Sec. 18 T153N, '
#           'R100W',
#   'oil_bbl': None,
#   'operator': None,
#   'production_dates_on_file': None,
#   'url': None,
#   'well_name': "Location: E levation: KB: 2,082' Formation/ Zone Kibbey Lime "
#                "8,382' -6,300' 183' 2,368' Charles Salt 8,565' -6,483' 642' "
#                "2,185' Base Last Salt 9,207' -7,125' 223' 1,543' Mission "
#                "Canyon 9,430' -7,348' 567' 1,320' Lodgepole 9,997' -7,915' "
#                "708' 753' False Bakken 10,705' -8,623' 7' 45' Upper Bakken "
#                "Shale 10,712' -8,630' 18' 38' Middle Bakken 10,730' -8,648' "
#                "40' 20' Control Well McKenzie Co., ND Oasis Petroleum Kline "
#                'Federal 5300 41-18 11T2 SW SW Sec. 18 T153N, R100W E st. T VD '
#                'Approximately 25 ft South MSL Datum T hickness Dist to target '
#                "KB: 2,082' 8,384 -6,302' 172' 2,361' 8,556 -6,474' 650' 2,189' "
#                "9,206 -7,124' 222' 1,539' 9,428 -7,346' 547' 1,317' 9,975 "
#                "-7,893' 729' 770' 10,704 -8,622' 9' 41' 10,713 -8,631' 17' 32' "
#                "10,730 -8,648' 27' 15' Upper Bakken Shale Middle Bakken Kibbey "
#                'Lime Formation/Zone Approximately 50 feet South MSL Datum E '
#                'levation: McKenzie Co., ND Lodgepole Charles Salt Mission '
#                'Canyon Base Last Salt False Bakken Control Well T hickness '
#                'Dist to targetE st. T VD Oasis Petroleum Kline Federal 5300 '
#                '41-18 12TX SW SW Sec. 18 T153N, R100W',
#   'well_status': None,
#   'well_type': None},
#  {'api': '33-053-06028',
#   'api_no': '33-053-06028',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': None,
#   'name': '24-HOUR PRODUCTION RATE Kline Federal 5300 41-18 13T2X Before After '
#           "Footages IQtr-Qtr I Section · ITownsh_ip 'Range . _ 401 F s L 237 F "
#           'w L LOT4 18 . · 153 N 100 w Oil Bbls Oil Water Bbls Water Field I '
#           'Pool I County Baker Bakken McKenzie Gas MCF Gas Name of Contractor '
#           '(s)',
#   'oil_bbl': None,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'August 2015 to July 2024',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/kline-federal-5300-41-18-13t2x/33-053-06028',
#   'well_name': 'Kline Federal 5300 41-18 13T2X',
#   'well_status': 'Plugged and Abandoned',
#   'well_type': 'Oil & Gas'},
#  {'api': None,
#   'api_no': None,
#   'closest_city': None,
#   'county': None,
#   'gas_mcf': None,
#   'name': '24-HOUR PRODUCTION RATE Kline Federal 5300 41-18 14BX Before After '
#           'Footages IQtr-Qtr 1$ectiori · !Township range . 368 F s L 237 F w L '
#           '.LOT4 .·. ·18 .. • 1.53 N 100 w Oil Bbls. Oil Bbls Water . Bbls . '
#           "Water Bbls Field IPool · · ICountY ' · Baker Bakken McKenzie Ga5 · "
#           'MCF Gas MCF Name of Contractor(s)',
#   'oil_bbl': None,
#   'operator': None,
#   'production_dates_on_file': None,
#   'url': None,
#   'well_name': '24-HOUR PRODUCTION RATE Kline Federal 5300 41-18 14BX Before '
#                'After Footages IQtr-Qtr 1$ectiori · !Township range . 368 F s '
#                'L 237 F w L .LOT4 .·. ·18 .. • 1.53 N 100 w Oil Bbls. Oil Bbls '
#                "Water . Bbls . Water Bbls Field IPool · · ICountY ' · Baker "
#                'Bakken McKenzie Ga5 · MCF Gas MCF Name of Contractor(s)',
#   'well_status': None,
#   'well_type': None},
#  {'api': None,
#   'api_no': None,
#   'closest_city': None,
#   'county': None,
#   'gas_mcf': None,
#   'name': 'Kline Federal 5300 41-18 12TX Footages ·IQtr-Qtr · !Section '
#           "r0W1'.1Ship I Range 434 F s L 237 F w L LOT4 . ·. 18 . 163 N 100 w "
#           "Field I Pool ·• -icourity . Baker Bakken ·. McKenzie . , .. ' Name "
#           'of Contractor(s ) ··, . ..',
#   'oil_bbl': None,
#   'operator': None,
#   'production_dates_on_file': None,
#   'url': None,
#   'well_name': 'Kline Federal 5300 41-18 12TX Footages ·IQtr-Qtr · !Section '
#                "r0W1'.1Ship I Range 434 F s L 237 F w L LOT4 . ·. 18 . 163 N "
#                '100 w Field I Pool ·• -icourity . Baker Bakken ·. McKenzie . , '
#                ".. ' Name of Contractor(s ) ··, . ..",
#   'well_status': None,
#   'well_type': None},
#  {'api': None,
#   'api_no': None,
#   'closest_city': None,
#   'county': None,
#   'gas_mcf': None,
#   'name': 'D Deepened Well D Other: Spacing Unit Description D Extended '
#           'Horizontal Leg Wade Federal 5300 41-30 9B Sec. 29/30/31/32 T153N '
#           'R100W',
#   'oil_bbl': None,
#   'operator': None,
#   'production_dates_on_file': None,
#   'url': None,
#   'well_name': 'D Deepened Well D Other: Spacing Unit Description D Extended '
#                'Horizontal Leg Wade Federal 5300 41-30 9B Sec. 29/30/31/32 '
#                'T153N R100W',
#   'well_status': None,
#   'well_type': None},
#  {'api': '33-053-00605',
#   'api_no': '33-053-00605',
#   'closest_city': 'Medora',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': None,
#   'name': 'Kline Federal 5300 31-18 8B',
#   'oil_bbl': None,
#   'operator': 'SM Energy Company',
#   'production_dates_on_file': 'April 1973 to September 2016',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/wrrmu-4-28/33-053-00605',
#   'well_name': 'Wrrmu 4-28',
#   'well_status': 'Plugged and Abandoned',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06056',
#   'api_no': '33-053-06056',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 1100,
#   'name': 'KLINE FEDERAL 5300 31-18 7T',
#   'oil_bbl': 285,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'September 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/kline-federal-5300-31-18-7t/33-053-06056',
#   'well_name': 'Kline Federal 5300 31-18 7T',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06057',
#   'api_no': '33-053-06057',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': None,
#   'name': 'Kline Federal 5300 31-18 6B D D D D D D D RE E I ED FEB 0 3 2017 ND '
#           'Oil & Gas Div. Drilling Prognosis D Redrilling or Repair D Casing '
#           'or Liner D Plug Well D Supplemental History 0 Temporarily Abandon D '
#           'IWell File No. 28756 Spill Report Shooting Acidizing Fracture '
#           'Treatment Change Production Method Reclamation Other Well is now on '
#           "pump 24-HOUR PRODUCTION RATE Before After Footages 'Qtr-Qtr "
#           "'Section 'Township 'Range 2457 F s L · 238 F W L LOT3 18 153 N 100 "
#           "w Oil Bbls Oil Water Bbls Water Field 'Pool 'County Baker Bakken "
#           'McKenzie Name of Contractor(s)',
#   'oil_bbl': None,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'September 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/kline-federal-5300-31-18-6b/33-053-06057',
#   'well_name': 'Kline Federal 5300 31-18 6B',
#   'well_status': 'Abandoned',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06129',
#   'api_no': '33-053-06129',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 1900,
#   'name': 'Wade Federal 5300 21-30 12T D D D D D D Received FEB 1 2 2016 !JD '
#           'OH & Gas Divi~ion Drilling Prognosis D Redrilling or Repair D '
#           'Casing or Liner D Plug Well D Supplemental History 0 Temporarily '
#           'Abandon D IWell File No. 28976 Spill Report Shooting Acid izing '
#           'Fracture Treatment Change Production Method Reclamation D Other '
#           'Well is now on pump 24-HOUR PRODUCTION RATE Before After Footages '
#           "'Qtr-Qtr 'Section rownship 'Range 1640 F N L 270 F W L · LOT2 30 "
#           '153 N 100 w Oil BQls Oil Water Bbls Water Field I Pool I County '
#           'Baker Bakken McKenzie Gas MCF Gas .. Name of Contractor(s)',
#   'oil_bbl': 501,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'May 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/wade-federal-5300-21-30-12t/33-053-06129',
#   'well_name': 'Wade Federal 5300 21-30 12T',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06131',
#   'api_no': '33-053-06131',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 245,
#   'name': 'WADE FEDERAL 5300 21-30 13B',
#   'oil_bbl': 50,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'April 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/wade-federal-5300-21-30-13b/33-053-06131',
#   'well_name': 'Wade Federal 5300 21-30 13B',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06223',
#   'api_no': '33-053-06223',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 2400,
#   'name': 'Kline Federal 5300 11-18 5B',
#   'oil_bbl': 318,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'August 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/kline-federal-5300-11-18-5b/33-053-06223',
#   'well_name': 'Kline Federal 5300 11-18 5B',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06225',
#   'api_no': '33-053-06225',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 743,
#   'name': 'Kline Federal 5300 11-18 3T',
#   'oil_bbl': 158,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'August 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/kline-federal-5300-11-18-3t/33-053-06225',
#   'well_name': 'Kline Federal 5300 11-18 3T',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06231',
#   'api_no': '33-053-06231',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 3800,
#   'name': 'Gramma Federal 5300 41-3112B Footages 647 F s L 320 F w IQtr-Qtr L '
#           'LOT4 I Section . 31 rownship 153 N I Range . 100 w . Field Baker I '
#           'Pool Bakken I County McKenzie Name of Contractor(s)',
#   'oil_bbl': 723,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'June 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/gramma-federal-5300-41-31-12b/33-053-06231',
#   'well_name': 'Gramma Federal 5300 41-31 12B',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06232',
#   'api_no': '33-053-06232',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 2900,
#   'name': 'Qtr-Qtr Section Township Range County '
#           '~G~RA=....::.:.M~M~A~F~E~D~E~RA~L~53~0~0 '
#           '~4~1-~31..:.....;.;13~T-1=-~~~~~~..__~~L~O~T~4~___,_~~31.:___,_-15~3~.__~~1~00;.;....a.__',
#   'oil_bbl': 357,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'July 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/gramma-federal-5300-41-31-13t/33-053-06232',
#   'well_name': 'Gramma Federal 5300 41-31 13T',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06243',
#   'api_no': '33-053-06243',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 1900,
#   'name': 'Kline Federal 5300 11-18 2B Footages IQtr-Qtr ISect~o~ !Township '
#           'range 960 F N L 318 F W L Lot 1 153 N 100 w Field I Pool I County '
#           'Baker Bakken McKenzie Name of Contractor(s)',
#   'oil_bbl': 206,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'September 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/kline-federal-5300-11-18-2b/33-053-06243',
#   'well_name': 'Kline Federal 5300 11-18 2B',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06548',
#   'api_no': '33-053-06548',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 4200,
#   'name': '& No. API # County & State SDI Job # Rig Survey Date I, , having '
#           'personal knowledge of all the facts, hereby 0 feet to a 2743 Seth '
#           'M. Burstad Rockies Region Well Planner Scientific Drilling - Rocky '
#           'Mountain District Survey Certification 7327 West Barton Road '
#           'Casper, WY 82604 Seth M. Burstad certify that the attached '
#           'directional survey run from a measured depth of measured depth of '
#           'feet is true and correct as determined from a ll available records. '
#           'Date 22-Jan-2019 Nabors B21 Lewis Federal 5300 11-31 3B McKenzie '
#           'County, ND Oasis Petroleum Signature 22-Jan-2019 33-053-06548 '
#           'OP.05419',
#   'oil_bbl': 1800,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'September 2019 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/lewis-federal-5300-11-31-3b/33-053-06548',
#   'well_name': 'Lewis Federal 5300 11-31 3B',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06549',
#   'api_no': '33-053-06549',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 3900,
#   'name': '& No. API # County & State SDI Job # Rig Survey Date I, , having '
#           'personal knowledge of all the facts, hereby 0 feet to a 20870 Seth '
#           'M. Burstad Rockies Region Well Planner Scientific Drilling - Rocky '
#           'Mountain District Nabors B21 Lewis Federal 5300 11-31 2B McKenzie '
#           'County, ND Oasis Petroleum Signature 12-Feb-2019 33-053-06549 '
#           'OP.015962 Date 14-Feb-2019 Survey Certification 7327 West Barton '
#           'Road Casper, WY 82604 Seth M. Burstad certify that the attached '
#           'directional survey run from a measured depth of measured depth of '
#           'feet is true and correct as determined from all available records.',
#   'oil_bbl': 711,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'September 2019 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/lewis-federal-5300-11-31-2b/33-053-06549',
#   'well_name': 'Lewis Federal 5300 11-31 2B',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-06755',
#   'api_no': '33-053-06755',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 1800,
#   'name': 'KLINE FEDERAL 5300 31-18 15T',
#   'oil_bbl': 489,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'September 2015 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/kline-federal-5300-31-18-15t/33-053-06755',
#   'well_name': 'Kline Federal 5300 31-18 15T',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-08946',
#   'api_no': '33-053-08946',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': 1700,
#   'name': '& No. API # County & State SDI Job # Rig Survey Date I, , having '
#           'personal knowledge of all the facts, hereby 0 feet to a 16577 Seth '
#           'M. Burstad Rockies Region Well Planner Scientific Drilling - Rocky '
#           'Mountain District Survey Certification 7327 West Barton Road '
#           'Casper, WY 82604 Seth M. Burstad certify that the attached '
#           'directional survey run from a measured depth of measured depth of '
#           'feet is true and correct as determined from a ll available records. '
#           'Date 14-Mar-2019 Nabors B21 Lewis Federal 5300 11-31 4BR OH '
#           'McKenzie County, ND Oasis Petroleum Signature 14-Mar-2019 '
#           '33-053-08946 OP.016663',
#   'oil_bbl': 511,
#   'operator': 'Oasis Petroleum North America LLC',
#   'production_dates_on_file': 'September 2019 to December 2025',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/lewis-federal-5300-11-31-4br/33-053-08946',
#   'well_name': 'Lewis Federal 5300 11-31 4BR',
#   'well_status': 'Active',
#   'well_type': 'Oil & Gas'},
#  {'api': '33-053-90244',
#   'api_no': '33-053-90244',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': None,
#   'name': 'BUCK SHOT SWD 5300 31-31',
#   'oil_bbl': None,
#   'operator': 'Falcon Midstream Services LLC',
#   'production_dates_on_file': 'No Production Data Available',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/buck-shot-swd-5300-31-31/33-053-90244',
#   'well_name': 'Buck Shot SWD 5300 31-31',
#   'well_status': 'Active',
#   'well_type': 'Salt Water Disposal'},
#  {'api': None,
#   'api_no': None,
#   'closest_city': None,
#   'county': None,
#   'gas_mcf': None,
#   'name': 'Atlanta #1 SWD Footages IQtr-Qtr I Section !Township !Range 260 F N '
#           "L 432 F W L NWNW 6 153 N 101 W Field 'Pool 'County Baker Dakota "
#           'Williams Name of Contractor(s)',
#   'oil_bbl': None,
#   'operator': None,
#   'production_dates_on_file': None,
#   'url': None,
#   'well_name': 'Atlanta #1 SWD Footages IQtr-Qtr I Section !Township !Range '
#                "260 F N L 432 F W L NWNW 6 153 N 101 W Field 'Pool 'County "
#                'Baker Dakota Williams Name of Contractor(s)',
#   'well_status': None,
#   'well_type': None},
#  {'api': None,
#   'api_no': '33-053-90329',
#   'closest_city': 'Williston',
#   'county': 'McKenzie County, ND',
#   'gas_mcf': None,
#   'name': 'Carson SWD 5301 12-24',
#   'oil_bbl': None,
#   'operator': 'Falcon Midstream Services LLC',
#   'production_dates_on_file': 'No Production Data Available',
#   'url': 'https://www.drillingedge.com/north-dakota/mckenzie-county/wells/carson-swd-5301-12-24/33-053-90329',
#   'well_name': 'Carson SWD 5301 12-24',
#   'well_status': 'Active',
#   'well_type': 'Salt Water Disposal'}]
